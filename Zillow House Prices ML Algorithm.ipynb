# %% [markdown]
# # Zillow House Price Prediction Using Tensorflow

# %% [markdown]
# The objective of this project is to create a machine learning algorithm using tensorflow to predict house prices based on the number of bedrooms.

# %% [markdown]
# ## The Dataset
#
# This data was acquired from Zillow's official website. Initially, I will have 5 different datasets with each set containing data specific to each bedroom count. The datasets originally have monthly housing prices for each state ranging from 2000 - 2023. Since this is a large dataset, my focus will be on the state of Georgia. Before working with any data, I will clean the datasets to make sure the predictions are accurate.

# %% [markdown]
# ## Cleaning and Visualization
#
# Let's take a look at the datasets.

# %%
import numpy as np
import pandas as pd

# %%
bedroom_1 = pd.read_csv('/Users/hannatuple/Desktop/Python/1_bedroom.csv')
bedroom_1.head()
# Out:
#    RegionID  SizeRank    RegionName RegionType  StateName    2000-01-31
# 0         9         0    California      state        NaN  93901.169254  \
# 1        54         1         Texas      state        NaN  48114.904911
# 2        14         2       Florida      state        NaN  45273.978240
# 3        43         3      New York      state        NaN  55750.776963
# 4        47         4  Pennsylvania      state        NaN  50011.867104
#
#      2000-02-29    2000-03-31    2000-04-30    2000-05-31  ...     2022-06-30
# 0  94257.445914  94739.305237  95820.282523  97108.179159  ...  470370.606531  \
# 1  48189.302787  48218.560485  48190.656701  48121.706231  ...  142817.246930
# 2  45371.466701  45481.318684  45730.066189  45996.468076  ...  194322.187250
# 3  56007.915833  56231.037665  56691.526060  57134.557411  ...  349396.656167
# 4  50134.501232  50227.761965  50428.560380  50624.668256  ...  156617.769240
#
# ...

# %%
bedroom_2 = pd.read_csv('/Users/hannatuple/Desktop/Python/2_bedroom.csv')
bedroom_2.head()
# Out:
#    RegionID  SizeRank    RegionName RegionType  StateName     2000-01-31
# 0         9         0    California      state        NaN  138998.485601  \
# 1        54         1         Texas      state        NaN   56566.423012
# 2        14         2       Florida      state        NaN   72736.979994
# 3        43         3      New York      state        NaN   93640.358672
# 4        47         4  Pennsylvania      state        NaN   62886.155653
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...
# 0  139468.546309  140114.970956  141533.228220  143191.295319  ...  \
# 1   56572.293098   56550.065161   56541.638148   56477.072243  ...
# 2   72890.685731   73071.082298   73443.904333   73843.926488  ...
# 3   93901.271720   94138.358678   94668.643435   95214.666721  ...
# 4   63016.753489   63141.967063   63404.592899   63647.209611  ...
#
#       2022-06-30     2022-07-31     2022-08-31     2022-09-30     2022-10-31
# ...

# %%
bedroom_3 = pd.read_csv('/Users/hannatuple/Desktop/Python/3_bedroom.csv')
bedroom_3.head()
# Out:
#    RegionID  SizeRank    RegionName RegionType  StateName     2000-01-31
# 0         9         0    California      state        NaN  174378.777099  \
# 1        54         1         Texas      state        NaN   97575.107288
# 2        14         2       Florida      state        NaN  108598.320096
# 3        43         3      New York      state        NaN  103069.582603
# 4        47         4  Pennsylvania      state        NaN   86629.229227
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...
# 0  174928.844933  175699.991649  177358.164727  179300.915772  ...  \
# 1   97633.205131   97653.775206   97776.772727   97842.893725  ...
# 2  108857.065151  109150.645024  109732.604832  110335.713502  ...
# 3  103305.589393  103552.237965  104121.966625  104747.260096  ...
# 4   86808.305171   86978.460603   87322.450838   87683.879708  ...
#
#       2022-06-30     2022-07-31     2022-08-31     2022-09-30     2022-10-31
# ...

# %%
bedroom_4 = pd.read_csv('/Users/hannatuple/Desktop/Python/4_bedroom.csv')
bedroom_4.head()
# Out:
#    RegionID  SizeRank    RegionName RegionType  StateName     2000-01-31
# 0         9         0    California      state        NaN  241721.294474  \
# 1        54         1         Texas      state        NaN  166402.440377
# 2        14         2       Florida      state        NaN  152634.066491
# 3        43         3      New York      state        NaN  153650.757934
# 4        47         4  Pennsylvania      state        NaN  148316.281715
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...
# 0  242618.435223  243728.182373  246158.651178  248880.540538  ...  \
# 1  166447.232223  166461.884090  166642.182610  166730.524734  ...
# 2  153033.736636  153461.506508  154312.574742  155171.821295  ...
# 3  154151.649825  154629.938778  155710.983377  156850.659017  ...
# 4  148694.928520  149047.243380  149799.444129  150593.061397  ...
#
#       2022-06-30     2022-07-31     2022-08-31     2022-09-30     2022-10-31
# ...

# %%
bedroom_5_plus = pd.read_csv('/Users/hannatuple/Desktop/Python/5+_bedroom.csv')
bedroom_5_plus.head()
# Out:
#    RegionID  SizeRank    RegionName RegionType  StateName     2000-01-31
# 0         9         0    California      state        NaN  326241.955099  \
# 1        54         1         Texas      state        NaN  244142.051193
# 2        14         2       Florida      state        NaN  227946.045407
# 3        43         3      New York      state        NaN  202986.678338
# 4        47         4  Pennsylvania      state        NaN  153939.218526
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...
# 0  327487.573428  329042.236010  332508.257433  336440.293654  ...  \
# 1  244177.107139  244134.041296  244305.793232  244324.542901  ...
# 2  228527.931540  229252.694547  230664.838909  232149.551142  ...
# 3  203928.632740  204864.948018  206775.022024  208708.370087  ...
# 4  154336.282534  154729.007216  155552.974266  156423.773514  ...
#
#      2022-06-30    2022-07-31    2022-08-31    2022-09-30    2022-10-31
# ...

# %% [markdown]
# Looking at all the datasets, there seems to be some unnecessary columns. The datasets are strictly for each state so I will remove **RegionType**. It appears that **StateName** has null values and can be dropped. For this project, both **RegionID** and **SizeRank** are irrelevant and will be removed. Additionally, I will round the price values for readability and efficiency.

# %%
bedroom_1 = bedroom_1.dropna(axis="columns", how="all")
bedroom_1 = bedroom_1.drop(columns=["RegionID", "SizeRank", "RegionType"])
bedroom_1 = bedroom_1.round()
bedroom_1.head()
# Out:
#      RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 0    California     93901.0     94257.0     94739.0     95820.0     97108.0  \
# 1         Texas     48115.0     48189.0     48219.0     48191.0     48122.0
# 2       Florida     45274.0     45371.0     45481.0     45730.0     45996.0
# 3      New York     55751.0     56008.0     56231.0     56692.0     57135.0
# 4  Pennsylvania     50012.0     50135.0     50228.0     50429.0     50625.0
#
#    2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2022-06-30
# 0     98532.0    100016.0    101553.0    103086.0  ...    470371.0  \
# 1     47981.0     48079.0     48207.0     48404.0  ...    142817.0
# 2     46283.0     46550.0     46809.0     47081.0  ...    194322.0
# 3     57651.0     58156.0     58576.0     58884.0  ...    349397.0
# 4     50827.0     51068.0     51276.0     51528.0  ...    156618.0
#
#    2022-07-31  2022-08-31  2022-09-30  2022-10-31  2022-11-30  2022-12-31
# ...

# %%
bedroom_2 = bedroom_2.dropna(axis="columns", how="all")
bedroom_2 = bedroom_2.drop(columns=["RegionID", "SizeRank", "RegionType"])
bedroom_2 = bedroom_2.round()
bedroom_2.head()
# Out:
#      RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 0    California    138998.0    139469.0    140115.0    141533.0    143191.0  \
# 1         Texas     56566.0     56572.0     56550.0     56542.0     56477.0
# 2       Florida     72737.0     72891.0     73071.0     73444.0     73844.0
# 3      New York     93640.0     93901.0     94138.0     94669.0     95215.0
# 4  Pennsylvania     62886.0     63017.0     63142.0     63405.0     63647.0
#
#    2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2022-06-30
# 0    144972.0    146843.0    148759.0    150641.0  ...    613715.0  \
# 1     56422.0     56401.0     56477.0     56587.0  ...    178388.0
# 2     74238.0     74630.0     75024.0     75447.0  ...    280946.0
# 3     95815.0     96323.0     96722.0     97023.0  ...    276102.0
# 4     63871.0     64105.0     64341.0     64599.0  ...    175583.0
#
#    2022-07-31  2022-08-31  2022-09-30  2022-10-31  2022-11-30  2022-12-31
# ...

# %%
bedroom_3 = bedroom_3.dropna(axis="columns", how="all")
bedroom_3 = bedroom_3.drop(columns=["RegionID", "SizeRank", "RegionType"])
bedroom_3 = bedroom_3.round()
bedroom_3.head()
# Out:
#      RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 0    California    174379.0    174929.0    175700.0    177358.0    179301.0  \
# 1         Texas     97575.0     97633.0     97654.0     97777.0     97843.0
# 2       Florida    108598.0    108857.0    109151.0    109733.0    110336.0
# 3      New York    103070.0    103306.0    103552.0    104122.0    104747.0
# 4  Pennsylvania     86629.0     86808.0     86978.0     87322.0     87684.0
#
#    2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2022-06-30
# 0    181398.0    183625.0    185966.0    188298.0  ...    731162.0  \
# 1     97923.0     97966.0     98132.0     98364.0  ...    278958.0
# 2    110947.0    111567.0    112202.0    112860.0  ...    382933.0
# 3    105437.0    105973.0    106395.0    106718.0  ...    281765.0
# 4     88047.0     88429.0     88780.0     89140.0  ...    237830.0
#
#    2022-07-31  2022-08-31  2022-09-30  2022-10-31  2022-11-30  2022-12-31
# ...

# %%
bedroom_4 = bedroom_4.dropna(axis="columns", how="all")
bedroom_4 = bedroom_4.drop(columns=["RegionID", "SizeRank", "RegionType"])
bedroom_4 = bedroom_4.round()
bedroom_4.head()
# Out:
#      RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 0    California    241721.0    242618.0    243728.0    246159.0    248881.0  \
# 1         Texas    166402.0    166447.0    166462.0    166642.0    166731.0
# 2       Florida    152634.0    153034.0    153462.0    154313.0    155172.0
# 3      New York    153651.0    154152.0    154630.0    155711.0    156851.0
# 4  Pennsylvania    148316.0    148695.0    149047.0    149799.0    150593.0
#
#    2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2022-06-30
# 0    251813.0    254861.0    258093.0    261356.0  ...    930310.0  \
# 1    166819.0    166809.0    167014.0    167330.0  ...    420604.0
# 2    156068.0    157001.0    157960.0    158931.0  ...    510235.0
# 3    158069.0    159032.0    159831.0    160534.0  ...    443166.0
# 4    151434.0    152288.0    153077.0    153845.0  ...    400208.0
#
#    2022-07-31  2022-08-31  2022-09-30  2022-10-31  2022-11-30  2022-12-31
# ...

# %%
bedroom_5_plus = bedroom_5_plus.dropna(axis="columns", how="all")
bedroom_5_plus = bedroom_5_plus.drop(columns=["RegionID", "SizeRank", "RegionType"])
bedroom_5_plus = bedroom_5_plus.round()
bedroom_5_plus.head()
# Out:
#      RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 0    California    326242.0    327488.0    329042.0    332508.0    336440.0  \
# 1         Texas    244142.0    244177.0    244134.0    244306.0    244325.0
# 2       Florida    227946.0    228528.0    229253.0    230665.0    232150.0
# 3      New York    202987.0    203929.0    204865.0    206775.0    208708.0
# 4  Pennsylvania    153939.0    154336.0    154729.0    155553.0    156424.0
#
#    2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2022-06-30
# 0    340678.0    345059.0    349591.0    354127.0  ...   1258617.0  \
# 1    244408.0    244381.0    244729.0    245153.0  ...    631114.0
# 2    233597.0    235103.0    236609.0    238204.0  ...    767316.0
# 3    210646.0    212449.0    214117.0    215754.0  ...    692990.0
# 4    157326.0    158274.0    159179.0    160067.0  ...    460374.0
#
#    2022-07-31  2022-08-31  2022-09-30  2022-10-31  2022-11-30  2022-12-31
# ...

# %% [markdown]
# Now, I want to filter out any rows that have missing values and compare the datasets.

# %%
bedroom_1.loc[bedroom_1.isnull().any(axis=1)]
# Out:
#       RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 3       New York     55751.0     56008.0     56231.0     56692.0     57135.0  \
# 5       Illinois     65162.0     65240.0     65451.0     65923.0     66516.0
# 16       Indiana         NaN         NaN         NaN         NaN         NaN
# 24     Louisiana     72461.0     72354.0     72428.0     72675.0     73151.0
# 27      Oklahoma     18088.0     18099.0     18124.0     18158.0     18229.0
# 28   Connecticut     66372.0     66754.0     66849.0     67142.0     67370.0
# 30          Iowa     39656.0     39592.0     39706.0     39848.0     40098.0
# 31        Nevada     72945.0     72974.0     73008.0     73141.0     73320.0
# 33   Mississippi         NaN         NaN         NaN         NaN         NaN
# 34        Kansas     34257.0     34358.0     34410.0     34490.0     34542.0
# 35    New Mexico         NaN         NaN         NaN         NaN         NaN
# ...

# %%
bedroom_2.loc[bedroom_2.isnull().any(axis=1)]
# Out:
#       RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 16       Indiana         NaN         NaN         NaN         NaN     53975.0  \
# 24     Louisiana     61914.0     61977.0     62050.0     62244.0     62553.0
# 28   Connecticut    110033.0    110445.0    110874.0    111633.0    112264.0
# 33   Mississippi         NaN         NaN         NaN         NaN         NaN
# 34        Kansas     45201.0     45157.0     45132.0     45154.0     45213.0
# 35    New Mexico         NaN         NaN         NaN         NaN         NaN
# 39        Hawaii    143337.0    143229.0    143415.0    143720.0    144418.0
# 43       Montana         NaN         NaN         NaN         NaN         NaN
# 44      Delaware     93857.0     93986.0     94153.0     94545.0     95029.0
# 45  South Dakota         NaN         NaN         NaN         NaN         NaN
# 46  North Dakota         NaN         NaN         NaN         NaN         NaN
# ...

# %%
bedroom_3.loc[bedroom_3.isnull().any(axis=1)]
# Out:
#        RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 13        Arizona    126957.0    127205.0    127512.0    128128.0    128815.0  \
# 34         Kansas     74750.0     74762.0     74857.0     74998.0     75202.0
# 35     New Mexico         NaN         NaN         NaN         NaN         NaN
# 37          Idaho    113901.0    113868.0    113953.0    114116.0    114489.0
# 38  West Virginia     68402.0     68425.0     68461.0     68549.0     68676.0
# 43        Montana         NaN         NaN         NaN         NaN         NaN
# 46   North Dakota         NaN         NaN         NaN         NaN         NaN
# 47         Alaska    131909.0    131998.0    132115.0    132311.0    132627.0
# 50        Wyoming         NaN         NaN         NaN         NaN         NaN
#
#     2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2022-06-30
# 13    129429.0    130070.0    130698.0    131392.0  ...    427682.0  \
# ...

# %%
bedroom_4.loc[bedroom_4.isnull().any(axis=1)]
# Out:
#       RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 13       Arizona    164446.0    164768.0    165182.0    165991.0    166860.0  \
# 28   Connecticut    233319.0    234343.0    235411.0    237304.0    238938.0
# 35    New Mexico         NaN         NaN         NaN         NaN         NaN
# 37         Idaho    143271.0    143064.0    143058.0    143041.0    143352.0
# 43       Montana         NaN         NaN         NaN         NaN         NaN
# 46  North Dakota         NaN         NaN         NaN         NaN         NaN
# 47        Alaska    169839.0    170111.0    170155.0    170260.0    170276.0
# 49       Vermont    124091.0    124185.0    124539.0    125210.0    126142.0
# 50       Wyoming         NaN         NaN         NaN         NaN         NaN
#
#     2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  2022-06-30
# 13    167594.0    168386.0    169131.0    169975.0  ...    529690.0  \
# ...

# %%
bedroom_5_plus.loc[bedroom_5_plus.isnull().any(axis=1)]
# Out:
#       RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31
# 1          Texas    244142.0    244177.0    244134.0    244306.0    244325.0  \
# 10    New Jersey    294691.0    295571.0    296425.0    298369.0    300626.0
# 28   Connecticut    378747.0    380625.0    382391.0    385655.0    388644.0
# 30          Iowa    144788.0    145118.0    145441.0    146125.0    146730.0
# 33   Mississippi         NaN         NaN         NaN         NaN         NaN
# 35    New Mexico         NaN         NaN         NaN         NaN         NaN
# 37         Idaho    162920.0    162801.0    162895.0    163044.0    163424.0
# 43       Montana         NaN         NaN         NaN         NaN         NaN
# 45  South Dakota         NaN         NaN         NaN         NaN         NaN
# 46  North Dakota         NaN         NaN         NaN         NaN         NaN
# 47        Alaska    199219.0    199416.0    199742.0    200001.0    200476.0
# ...

# %% [markdown]
# There are a lot of states that have missing values, but since I'm not merging the datasets I won't remove any of them. I'm strictly working with data from Georgia and Georgia is not missing any values so I can retreive the data I need from each dataset.

# %%
# Quick search to find the index of Georgia.
# Since the datasets are identical, Georgia will have the same index in all datasets.

bedroom_1.loc[bedroom_1.notna().any(axis=1)]
# Out:
#               RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30
# 0             California     93901.0     94257.0     94739.0     95820.0  \
# 1                  Texas     48115.0     48189.0     48219.0     48191.0
# 2                Florida     45274.0     45371.0     45481.0     45730.0
# 3               New York     55751.0     56008.0     56231.0     56692.0
# 4           Pennsylvania     50012.0     50135.0     50228.0     50429.0
# 5               Illinois     65162.0     65240.0     65451.0     65923.0
# 6                   Ohio     35585.0     35608.0     35655.0     35764.0
# 7                Georgia     67425.0     67680.0     67940.0     68511.0
# 8         North Carolina     57462.0     57641.0     57828.0     58134.0
# 9               Michigan     51462.0     51436.0     51539.0     51719.0
# 10            New Jersey     83363.0     83696.0     83991.0     84610.0
# 11              Virginia     75000.0     74832.0     74941.0     75198.0
# ...

# %%
# Making an array to store the prices for each bedroom count. 
# First object in the array is "Georgia", so it will have to be removed to change the object type.

bed_1 = pd.Series(bedroom_1.iloc[7].values)
del bed_1[0]
bed_1 = bed_1.astype("float32")

bed_2 = pd.Series(bedroom_2.iloc[7].values)
del bed_2[0]
bed_2 = bed_2.astype("float32")

bed_3 = pd.Series(bedroom_3.iloc[7].values)
del bed_3[0]
bed_3 = bed_3.astype("float32")

bed_4 = pd.Series(bedroom_4.iloc[7].values)
del bed_4[0]
bed_4 = bed_4.astype("float32")

bed_5 = pd.Series(bedroom_5_plus.iloc[7].values)
del bed_5[0]
bed_5 = bed_5.astype("float32")

bed_1.head()
# Out:
# 1    67425.0
# 2    67680.0
# 3    67940.0
# 4    68511.0
# 5    69096.0
# dtype: float32

# %% [markdown]
# ## The Algorithm
#
# Now that I have the data I need, I can work on my model.

# %%
# Installing required packages
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from keras.layers import Dense

# %%
# Plotting prices for each bedroom from 2000-2023

# X will be the same for all plots. 
x = pd.Series(bedroom_1.columns)
del x[0]
x = pd.to_datetime(x)

plt.style.use('seaborn')
fig, ax = plt.subplots(2,2)

# 1 Bedroom
y_1 = pd.Series(bed_1)
ax[0,0].plot(x, y_1)
ax[0,0].set_title("1 Bedroom House Prices in GA", fontsize=10)
ax[0,0].set_xlabel("Year", fontsize=8)
ax[0,0].set_ylabel("House Price", fontsize=8)
ax[0,0].tick_params(axis='both', which='major', labelsize=8)


# 2 Bedroom
y_2 = pd.Series(bed_2)
ax[0,1].plot(x, y_2)
ax[0,1].set_title("2 Bedroom House Prices in GA", fontsize=10)
ax[0,1].set_xlabel("Year", fontsize=8)
ax[0,1].set_ylabel("House Price", fontsize=8)
ax[0,1].tick_params(axis='both', which='major', labelsize=8)


# 3 Bedroom
y_3 = pd.Series(bed_3)
ax[1,0].plot(x, y_3)
ax[1,0].set_title("3 Bedroom House Prices in GA", fontsize=10)
ax[1,0].set_xlabel("Year", fontsize=8)
ax[1,0].set_ylabel("House Price", fontsize=8)
ax[1,0].tick_params(axis='both', which='major', labelsize=8)

# 4 Bedroom
y_4 = pd.Series(bed_4)
ax[1,1].plot(x, y_4)
ax[1,1].set_title("4 Bedroom House Prices in GA", fontsize=10)
ax[1,1].set_xlabel("Year", fontsize=8)
ax[1,1].set_ylabel("House Price", fontsize=8)
ax[1,1].tick_params(axis='both', which='major', labelsize=8)

fig.tight_layout()
plt.show()
# Out:
# /var/folders/xf/vc0d2yl549z5_9hz79n14h4m0000gn/T/ipykernel_14731/3758006594.py:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# When building the model, it's important to apply an algorithm that will fit the data. I will test Stochastic Gradient Descent and the Mean Squared Error as my optimizer and loss function. I currently only used the datasets for bedrooms ranging from 1-4. The reason for this is that I will use the dataset for 5 or more bedrooms to determine the accuracy of my model.

# %%
# Plot data for 5+ bedrooms.

plt.style.use('seaborn')
fig, ax = plt.subplots()

y_5 = pd.Series(bed_5)
ax.plot(x, y_5)
ax.set_title("5+ Bedroom House Prices in GA", fontsize=15)
ax.set_xlabel("Year", fontsize=10)
ax.set_ylabel("House Price", fontsize=10)
ax.tick_params(axis='both', which='major', labelsize=8)

plt.show()
# Out:
# /var/folders/xf/vc0d2yl549z5_9hz79n14h4m0000gn/T/ipykernel_14731/2905541633.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# I will use the average of each dataset to predict the average house price for 5+ bedrooms. 

bed_1_avg = bed_1.mean()
bed_2_avg = bed_2.mean()
bed_3_avg = bed_3.mean()
bed_4_avg = bed_4.mean()
bed_5_avg = bed_5.mean()

# %%
# Build Model
def house_model():
    
    x_train = np.array([1, 2, 3, 4])
    y_train = np.array([bed_1_avg, bed_2_avg, bed_3_avg, bed_4_avg])

    model = Sequential([
        Dense(units=1, input_shape=[1])
    ])
    
    model.compile(optimizer='sgd', loss='mean_squared_error')
    model.fit(x_train, y_train, epochs=2000)
    reduce_tracing = True
    
    return model

# %%
model = house_model()
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 455ms/step - loss: 22370035712.0000
# Epoch 2/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 15706805248.0000
# Epoch 3/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 11083220992.0000
# Epoch 4/2000
# 1/1 [==============================] - 0s 32ms/step - loss: 7874901504.0000
# Epoch 5/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 5648605184.0000
# Epoch 6/2000
# 1/1 [==============================] - 0s 16ms/step - loss: 4103715328.0000
# Epoch 7/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 3031640064.0000
# Epoch 8/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 2287640064.0000
# Epoch 9/2000
# 1/1 [==============================] - 0s 15ms/step - loss: 1771286272.0000
# Epoch 10/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 1412891520.0000
# Epoch 11/2000
# ...

# %%
new_x = 5
prediction = model.predict([new_x])
print(prediction)
# Out:
# 1/1 [==============================] - 0s 84ms/step
# [[244599.39]]

# %% [markdown]
# Now that I calculated the prediction, I can compare this price to the price listed in the 5+ bedroom dataset.

# %%
print(bed_5_avg)
# Out:
# 327425.38

# %% [markdown]
# The prediction was close but not very accurate. In this case, increasing the epochs wouldn't change the outcome so it is likely that this algorithm isn't the best to use with this data. The line of best fit would likely be curved rather than linear due to the drop in prices in 2012. Since I used only the average price and multiple datasets it's possible that the training sets were also skewed.
